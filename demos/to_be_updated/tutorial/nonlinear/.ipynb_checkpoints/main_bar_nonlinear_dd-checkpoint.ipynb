# %% [markdown]
# 0) **Imports**

# %%
import os, sys
from timeit import default_timer as timer
import dolfin as df # Fenics : dolfin + ufl + FIAT + ...
import numpy as np
import matplotlib.pyplot as plt
import copy 

# DDfenics imports
from ddfenics.dd.ddmaterial import DDMaterial 
from ddfenics.dd.ddmetric import DDMetric
from ddfenics.dd.ddfunction import DDFunction
from ddfenics.dd.ddbilinear import DDBilinear
from ddfenics.dd.ddproblem import DDProblem
from ddfenics.dd.ddsolver import DDSolver
from ddfenics.dd.ddspace import DDSpace
# Out:
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).

# %% [markdown]
# 1) **Consititutive behaviour Definition**

# %%
# fetricks is a set of utilitary functions to facilitate our lives
from fetricks.mechanics.elasticity_conversions import youngPoisson2lame
from fetricks import Id_mandel_np, tr_mandel

start = timer()
database_file = 'database_generated.txt' # database_ref.txt to sanity check

Nd = 100000 # number of points

E = 100.0
nu = 0.3
alpha = 10e4
lamb, mu = youngPoisson2lame(nu, E) 

np.random.seed(1)

eps_range = np.array([[-0.008,0.008], [-0.002, 0.002], [-0.0025, 0.00025]]).T
DD = np.zeros((Nd,2,3))

sigma_law = lambda e: (lamb*(1.0 + alpha*tr_mandel(e)**2)*tr_mandel(e)*Id_mandel_np + 
                      2*mu*(1 + alpha*np.dot(e,e))*e)

for i in range(Nd):
    DD[i,0,:] = eps_range[0,:] + np.random.rand(3)*(eps_range[1,:] - eps_range[0,:])
    DD[i,1,:] = sigma_law(DD[i,0,:])
    
np.savetxt(database_file, DD.reshape((-1,6)), header = '1.0 \n%d 2 3 3'%Nd, comments = '', fmt='%.8e', )

ddmat = DDMaterial(database_file)  # replaces sigma_law = lambda u : ...

end  = timer()
ddmat.plotDB()

print(end - start)
# Out:
# shuffling
# 1.2574425439997867

# %% [markdown]
# 2) **Mesh** (Unchanged)

# %%
Nx =  50 # x10
Ny =  10 # x10
Lx = 2.0
Ly = 0.5
mesh = df.RectangleMesh(df.Point(0.0,0.0) , df.Point(Lx,Ly), Nx, Ny, 'left/right');
df.plot(mesh);

# %% [markdown]
# 3) **Mesh regions** (Unchanged)

# %%
leftBnd = df.CompiledSubDomain('near(x[0], 0.0) && on_boundary')
rightBnd = df.CompiledSubDomain('near(x[0], Lx) && on_boundary', Lx=Lx)

clampedBndFlag = 1
loadBndFlag = 2
boundary_markers = df.MeshFunction("size_t", mesh, dim=1, value=0)
leftBnd.mark(boundary_markers, clampedBndFlag)
rightBnd.mark(boundary_markers, loadBndFlag)

dx = df.Measure('dx', domain=mesh)
ds = df.Measure('ds', domain=mesh, subdomain_data=boundary_markers)

# %% [markdown]
# 4) **Spaces**

# %%
Uh = df.VectorFunctionSpace(mesh, "Lagrange", 1) # Unchanged
bcL = df.DirichletBC(Uh, df.Constant((0.0, 0.0)), boundary_markers, clampedBndFlag) # Unchanged

# Space for stresses and strains
Sh0 = DDSpace(Uh, representation = 'DG', dim = 3)

# %% [markdown]
# 5) **Variational Formulation**: <br>
#
# - Strong format:
# $$
# \begin{cases}
# div \sigma = 0  \text{in} \, \Omega \\
# u = 0 \quad \text{on} \, \Gamma_1 \\
# \varepsilon = \nabla^s u \quad \text{in} \, \Omega \\
# \sigma  n  = t \quad \text{on} \, \Gamma_2 \\
# \end{cases}
# $$
# - DD equilibrium subproblem: Given $(\varepsilon^*, \sigma^*) \in Z_h$, solve for $(u,\eta) \in U_h$
# $$
# \begin{cases}
# (\mathbb{C} \nabla^s u , \nabla^s v ) = (\mathbb{C} \varepsilon^* , \nabla^s v ) \quad \forall v \in U_h, \\
# (\mathbb{C} \nabla^s \eta , \nabla^s \xi ) = \Pi_{ext}(\xi) - (\sigma^* , \nabla^s \xi ) \quad \forall \xi \in U_h \\
# \end{cases}
# $$
# - Updates:
# $$
# \begin{cases}
# \varepsilon = \nabla^s u \\
# \sigma = \sigma^* + \mathbb{C} \nabla^s \eta
# \end{cases}
# $$
# - DD ''bilinear'' form : $(\bullet , \nabla^s v)$ or sometimes  $(\mathbb{C} \nabla^s \bullet, \nabla^s v)$

# %%
# Unchanged
ty = -0.1
traction = df.Constant((0.0, ty))

u = df.TrialFunction(Uh) 
v = df.TestFunction(Uh)
b = df.inner(traction,v)*ds(loadBndFlag)

a = DDBilinear(ddmat, dx, u, v) # replaces df.inner(sig(u) , df.grad(v))*dx

# %% [markdown]
# 6) **Statement and Solving the problem** <br>
# - DDProblem : States DD equilibrium subproblem and updates.
# - DDSolver : Implements the alternate minimization using SKlearn NearestNeighbors('ball_tree', ...) searchs for the projection onto data.
# - Stopping criteria: $\|d_k - d_{k-1}\|/energy$

# %%
# Extended solution : replaces u = df.Function(Uh)
sol = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
       "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
       "u" : df.Function(Uh)} # displacemens

# replaces df.LinearVariationalProblem(a, b, uh, bcs = [bcL])
problem = DDProblem(a, b, sol, [bcL], metric = DDMetric(ddmat.C, omega = 0, V = Sh0, dx = dx), omega = 0.5) 

start = timer()
#replaces df.LinearVariationalSolver(problem)
solver = DDSolver(problem, opInit = 'zero')
tol_ddcm = 1e-7
hist, kmax, time_PE, time_PD = solver.solve(tol = tol_ddcm, maxit = 100);

end = timer()

uh = sol["u"]
normL2 = df.assemble(df.inner(uh,uh)*dx)

print("Time spent: ", end - start)
print("Norm L2: ", normL2)
print("Time PE: ", time_PE)
print("Time PD: ", time_PD)
# Out:
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  7.207217e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.316507e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.073274e-01
# 	Inner Iteration #  4 ,- Relative Error =  4.138189e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.052895e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.140033e-02
# 	Inner Iteration #  7 ,- Relative Error =  6.845940e-03
# 	Inner Iteration #  8 ,- Relative Error =  4.118186e-03
# 	Inner Iteration #  9 ,- Relative Error =  3.167901e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.497883e-03
# 	Inner Iteration # 11 ,- Relative Error =  9.525413e-04
# 	Inner Iteration # 12 ,- Relative Error =  6.822856e-04
# 	Inner Iteration # 13 ,- Relative Error =  5.050087e-04
# 	Inner Iteration # 14 ,- Relative Error =  3.559493e-04
# 	Inner Iteration # 15 ,- Relative Error =  2.794381e-04
# 	Inner Iteration # 16 ,- Relative Error =  2.289753e-04
# 	Inner Iteration # 17 ,- Relative Error =  6.176683e-05
# 	Inner Iteration # 18 ,- Relative Error =  5.679483e-05
# 	Inner Iteration # 19 ,- Relative Error =  1.478092e-05
# 	Inner Iteration # 20 ,- Relative Error =  3.326577e-06
# 	Inner Iteration # 21 ,- Relative Error =  0.000000e+00
# Time spent:  0.7308414640010596
# Time PE:  0.08565618400280073
# Time PD:  0.4712455899989436
# Norm L2:  0.00044466891391766914

# %%
print(hist.shape)
# Out:
# (1000, 1)

# %% [markdown]
# 7) **Postprocessing**

# %% [markdown]
# a) *Convergence*

# %%
hist = solver.hist

fig = plt.figure(1)
plt.title('Minimisation')
plt.plot(hist['relative_energy'], 'o-')
plt.xlabel('iterations')
plt.ylabel('energy gap')
plt.legend(loc = 'best')
plt.yscale('log')
plt.grid()

fig = plt.figure(2)
plt.title('Relative distance (wrt k-th iteration)')
plt.plot(hist['relative_distance'], 'o-', label = "relative_distance")
plt.plot([0,len(hist['relative_energy'])],[tol_ddcm,tol_ddcm])
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('rel. distance')
plt.legend(loc = 'best')
plt.grid()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# c) *Convergence with data*

# %%
relative_norm = lambda x1, x0: np.sqrt(df.assemble( df.inner(x1 - x0, x1 - x0)*dx ) )/np.sqrt(df.assemble( df.inner(x0, x0)*dx ) )

Nd_list = [10,100, 1000, 10000, 50000, 100000] 
hist_list = []
error_u = []
error_eps = []
error_sig = []

sol_ref_file =  df.XDMFFile("bar_nonlinear_sol.xdmf")
sol_ref = {"state" : [DDFunction(Sh0), DDFunction(Sh0)], "u" : df.Function(Uh)}   
sol_ref_file.read_checkpoint(sol_ref["u"],"u")
sol_ref_file.read_checkpoint(sol_ref["state"][0],"eps")
sol_ref_file.read_checkpoint(sol_ref["state"][1],"sig")

np.random.seed(1)


for Nd_i in Nd_list:
    indexes = np.arange(0,Nd).astype('int')
    np.random.shuffle(indexes)
    DD_i = DD[indexes[:Nd_i], : , : ]
    ddmat_i = DDMaterial(DD_i)
    
    a_i = DDBilinear(ddmat_i, dx, u, v) 

    sol_i = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
           "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
           "u" : df.Function(Uh)} # displacemens
    
    problem_i = DDProblem(a_i, b, sol_i, [bcL], metric = DDMetric(ddmat_i.C, V = Sh0, dx = dx, omega = 0.), omega = 0.5) 
    solver_i = DDSolver(problem_i, opInit = 'zero')
    solver_i.solve(tol = tol_ddcm, maxit = 100)
    
    hist_list.append(copy.deepcopy(solver_i.hist))
    
    error_u.append(relative_norm(sol_i["u"], sol_ref["u"])) 
    error_eps.append(relative_norm(sol_i["state_mech"][0], sol_ref["state"][0])) 
    error_sig.append(relative_norm(sol_i["state_mech"][1], sol_ref["state"][1]))
    
    
    
plt.figure(5)
plt.title('Energy gap VS database size')
plt.plot(Nd_list, [hist_list[i]['relative_energy'][-1] for i in range(len(Nd_list))], '-o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Nd')
plt.ylabel('energy gap')
plt.grid()

plt.figure(6)
plt.title('Relative L2 errors VS database size (wrt classical solutions)')
plt.plot(Nd_list, error_u, '-o', label = 'u')
plt.plot(Nd_list, error_eps, '-o', label = 'eps')
plt.plot(Nd_list, error_sig, '-o', label = 'sig')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Nd')
plt.ylabel('Errors')
plt.legend(loc = 'best')
plt.grid()
# Out:
# number of gauss points =  1
# number of gauss points =  1
# shuffling
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  8.726032e-01
# 	Inner Iteration #  2 ,- Relative Error =  7.439513e-02
# 	Inner Iteration #  3 ,- Relative Error =  3.130782e-02
# 	Inner Iteration #  4 ,- Relative Error =  1.193193e-02
# 	Inner Iteration #  5 ,- Relative Error =  5.016823e-03
# 	Inner Iteration #  6 ,- Relative Error =  1.906338e-03
# 	Inner Iteration #  7 ,- Relative Error =  2.186931e-03
# 	Inner Iteration #  8 ,- Relative Error =  1.006110e-03
# 	Inner Iteration #  9 ,- Relative Error =  1.670742e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.302702e-03
# 	Inner Iteration # 11 ,- Relative Error =  1.120283e-03
# 	Inner Iteration # 12 ,- Relative Error =  2.296270e-04
# 	Inner Iteration # 13 ,- Relative Error =  0.000000e+00
# shuffling
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  8.297338e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.423824e-01
# 	Inner Iteration #  3 ,- Relative Error =  6.588353e-02
# 	Inner Iteration #  4 ,- Relative Error =  3.124951e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.339883e-02
# 	Inner Iteration #  6 ,- Relative Error =  5.515435e-03
# 	Inner Iteration #  7 ,- Relative Error =  1.910650e-03
# 	Inner Iteration #  8 ,- Relative Error =  6.232279e-04
# 	Inner Iteration #  9 ,- Relative Error =  1.261566e-04
# 	Inner Iteration # 10 ,- Relative Error =  3.216071e-04
# 	Inner Iteration # 11 ,- Relative Error =  5.095659e-04
# 	Inner Iteration # 12 ,- Relative Error =  4.104726e-04
# 	Inner Iteration # 13 ,- Relative Error =  3.550593e-04
# 	Inner Iteration # 14 ,- Relative Error =  4.545851e-04
# 	Inner Iteration # 15 ,- Relative Error =  7.282238e-04
# 	Inner Iteration # 16 ,- Relative Error =  4.315284e-04
# 	Inner Iteration # 17 ,- Relative Error =  1.496932e-04
# 	Inner Iteration # 18 ,- Relative Error =  0.000000e+00
# shuffling
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  7.451358e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.120963e-01
# 	Inner Iteration #  3 ,- Relative Error =  8.373313e-02
# 	Inner Iteration #  4 ,- Relative Error =  2.989665e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.462739e-02
# 	Inner Iteration #  6 ,- Relative Error =  7.848766e-03
# 	Inner Iteration #  7 ,- Relative Error =  4.551803e-03
# 	Inner Iteration #  8 ,- Relative Error =  1.963043e-03
# 	Inner Iteration #  9 ,- Relative Error =  1.967281e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.814732e-03
# 	Inner Iteration # 11 ,- Relative Error =  1.275709e-03
# 	Inner Iteration # 12 ,- Relative Error =  5.767278e-04
# 	Inner Iteration # 13 ,- Relative Error =  1.828291e-04
# 	Inner Iteration # 14 ,- Relative Error =  9.543449e-05
# 	Inner Iteration # 15 ,- Relative Error =  2.390910e-04
# 	Inner Iteration # 16 ,- Relative Error =  1.014472e-04
# 	Inner Iteration # 17 ,- Relative Error =  1.392885e-04
# 	Inner Iteration # 18 ,- Relative Error =  0.000000e+00
# shuffling
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  7.294052e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.248961e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.038052e-01
# 	Inner Iteration #  4 ,- Relative Error =  3.746891e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.434695e-02
# 	Inner Iteration #  6 ,- Relative Error =  9.162561e-03
# 	Inner Iteration #  7 ,- Relative Error =  4.784420e-03
# 	Inner Iteration #  8 ,- Relative Error =  3.048348e-03
# 	Inner Iteration #  9 ,- Relative Error =  1.677326e-03
# 	Inner Iteration # 10 ,- Relative Error =  9.922711e-04
# 	Inner Iteration # 11 ,- Relative Error =  5.415429e-04
# 	Inner Iteration # 12 ,- Relative Error =  3.819119e-04
# 	Inner Iteration # 13 ,- Relative Error =  2.420046e-04
# 	Inner Iteration # 14 ,- Relative Error =  3.950390e-04
# 	Inner Iteration # 15 ,- Relative Error =  3.351133e-04
# 	Inner Iteration # 16 ,- Relative Error =  1.470453e-05
# 	Inner Iteration # 17 ,- Relative Error =  1.101183e-05
# 	Inner Iteration # 18 ,- Relative Error =  1.589766e-05
# 	Inner Iteration # 19 ,- Relative Error =  1.506881e-05
# 	Inner Iteration # 20 ,- Relative Error =  0.000000e+00
# shuffling
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  7.217751e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.307592e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.066807e-01
# 	Inner Iteration #  4 ,- Relative Error =  4.098754e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.923751e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.062412e-02
# 	Inner Iteration #  7 ,- Relative Error =  6.605277e-03
# 	Inner Iteration #  8 ,- Relative Error =  3.955191e-03
# 	Inner Iteration #  9 ,- Relative Error =  2.677764e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.631969e-03
# 	Inner Iteration # 11 ,- Relative Error =  9.486249e-04
# 	Inner Iteration # 12 ,- Relative Error =  4.894047e-04
# 	Inner Iteration # 13 ,- Relative Error =  3.487081e-04
# 	Inner Iteration # 14 ,- Relative Error =  2.017379e-04
# 	Inner Iteration # 15 ,- Relative Error =  6.690201e-05
# 	Inner Iteration # 16 ,- Relative Error =  5.362586e-05
# 	Inner Iteration # 17 ,- Relative Error =  4.980630e-05
# 	Inner Iteration # 18 ,- Relative Error =  3.590327e-05
# 	Inner Iteration # 19 ,- Relative Error =  5.286337e-05
# 	Inner Iteration # 20 ,- Relative Error =  3.903280e-06
# 	Inner Iteration # 21 ,- Relative Error =  5.452585e-07
# 	Inner Iteration # 22 ,- Relative Error =  5.744116e-07
# 	Inner Iteration # 23 ,- Relative Error =  0.000000e+00
# shuffling
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# number of gauss points =  1
# 	Inner Iteration #  1 ,- Relative Error =  7.207217e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.316507e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.073274e-01
# 	Inner Iteration #  4 ,- Relative Error =  4.138189e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.052895e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.140033e-02
# 	Inner Iteration #  7 ,- Relative Error =  6.845940e-03
# 	Inner Iteration #  8 ,- Relative Error =  4.118186e-03
# 	Inner Iteration #  9 ,- Relative Error =  3.167901e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.497883e-03
# 	Inner Iteration # 11 ,- Relative Error =  9.525413e-04
# 	Inner Iteration # 12 ,- Relative Error =  6.822856e-04
# 	Inner Iteration # 13 ,- Relative Error =  5.050087e-04
# 	Inner Iteration # 14 ,- Relative Error =  3.559493e-04
# 	Inner Iteration # 15 ,- Relative Error =  2.794381e-04
# 	Inner Iteration # 16 ,- Relative Error =  2.289753e-04
# 	Inner Iteration # 17 ,- Relative Error =  6.176683e-05
# 	Inner Iteration # 18 ,- Relative Error =  5.679483e-05
# 	Inner Iteration # 19 ,- Relative Error =  1.478092e-05
# 	Inner Iteration # 20 ,- Relative Error =  3.326576e-06
# 	Inner Iteration # 21 ,- Relative Error =  0.000000e+00

# %% [markdown]
# d) *sanity check*

# %%
state_mech = sol["state_mech"]
state_db = sol["state_db"]

fig,(ax1,ax2) = plt.subplots(1,2)
ax1.set_xlabel(r'$\epsilon_{xx}+\epsilon_{yy}$')
ax1.set_ylabel(r'$\sigma_{xx}+\sigma_{yy}$')
ax1.scatter(ddmat.DB[:, 0, 0] + ddmat.DB[:, 0, 1], ddmat.DB[:, 1, 0] + ddmat.DB[:, 1, 1], c='gray')
ax1.scatter(state_db[0].data()[:,0]+state_db[0].data()[:,1],state_db[1].data()[:,0]+state_db[1].data()[:,1], c='blue')
ax1.scatter(state_mech[0].data()[:,0]+state_mech[0].data()[:,1],state_mech[1].data()[:,0]+state_mech[1].data()[:,1], marker = 'x', c='black' )

ax2.set_xlabel(r'$\epsilon_{xy}$')
ax2.set_ylabel(r'$\sigma_{xy}$')
ax2.scatter(ddmat.DB[:, 0, 2], ddmat.DB[:, 1, 2], c='gray')
ax2.scatter(state_db[0].data()[:,2], state_db[1].data()[:,2], c='blue')
ax2.scatter(state_mech[0].data()[:,2], state_mech[1].data()[:,2], marker = 'x', c='black')

# %% [markdown]
# 8. **Sanity check:** : Recovering reference database

# %%
from ddfenics.dd.ddfunction import DDFunction

data = np.concatenate((sol_ref["state"][0].vector().get_local().reshape((-1,3)), 
                       sol_ref["state"][1].vector().get_local().reshape((-1,3))), axis = 1)

print(data.shape)
print(np.min(data[:,:3], axis = 0) )
print(np.max(data[:,:3], axis = 0) )

np.savetxt('database_ref.txt', data, header = '1.0 \n%d 2 3 3'%data.shape[0], comments = '', fmt='%.8e')
ddmat = DDMaterial('database_ref.txt') 
ddmat.plotDB()
# Out:
# (1000, 6)
# [-0.00663175 -0.00186831 -0.00202555]
# [6.63174608e-03 1.86830628e-03 7.64994252e-05]
# shuffling
