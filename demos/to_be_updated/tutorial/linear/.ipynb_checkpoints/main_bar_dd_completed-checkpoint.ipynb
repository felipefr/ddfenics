# %% [markdown]
# 0) **Imports**

# %%
import os, sys
from timeit import default_timer as timer
import dolfin as df # Fenics : dolfin + ufl + FIAT + ...
import numpy as np
import matplotlib.pyplot as plt
import copy
# Out:
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).

# %% [markdown]
# 1) **Material dataset (previous Constitutive behaviour)**

# %%
# fetricks is a set of utilitary functions to facilitate our lives
from fetricks.mechanics.elasticity_conversions import youngPoisson2lame
from ddfenics.dd.ddmaterial import DDMaterial # (missing line)  

database_file = 'database_generated.txt'

Nd = 100000 # number of points
noise = 0.01
eps_range = np.array([[-0.03,0.03], [-0.009, 0.009], [-0.012, 0.002]]).T
E = 100.0
nu = 0.3

lamb, mu = youngPoisson2lame(nu, E) 
Cmat = np.array( [[lamb + 2*mu, lamb, 0], [lamb, lamb + 2*mu, 0], [0, 0, 2*mu]] )

np.random.seed(1)
DD = np.zeros((Nd,2,3))

for i in range(Nd):
    DD[i,0,:] = eps_range[0,:] + np.random.rand(3)*(eps_range[1,:] - eps_range[0,:])
    DD[i,1,:] = Cmat@DD[i,0,:] + noise*np.random.randn(3)
    
np.savetxt(database_file, DD.reshape((-1,6)), header = '1.0 \n%d 2 3 3'%Nd, comments = '', fmt='%.8e', )

lamb, mu = youngPoisson2lame(0.3, 50.0) 
Cmat = np.array( [[lamb + 2*mu, lamb, 0], [lamb, lamb + 2*mu, 0], [0, 0, 2*mu]] )

ddmat = DDMaterial(DD, C = Cmat )

print("Error C estimation (SVD):", np.linalg.norm(Cmat - ddmat.C)/np.linalg.norm(Cmat))

ddmat.plotDB()
# Out:
# shuffling
# [[134.61538462  57.69230769   0.        ]
#  [ 57.69230769 134.61538462   0.        ]
#  [  0.           0.          76.92307692]]
# Error C estimation (SVD): 0.5678241298362041

# %% [markdown]
# 2) **Mesh** (Unchanged)

# %%
Nx =  50 # x10
Ny =  10 # x10
Lx = 2.0
Ly = 0.5
mesh = df.RectangleMesh(df.Point(0.0,0.0) , df.Point(Lx,Ly), Nx, Ny, 'left/right');
df.plot(mesh);

# %% [markdown]
# 3) **Mesh regions** (Unchanged)

# %%
leftBnd = df.CompiledSubDomain('near(x[0], 0.0) && on_boundary')
rightBnd = df.CompiledSubDomain('near(x[0], Lx) && on_boundary', Lx=Lx)

clampedBndFlag = 1
loadBndFlag = 2
boundary_markers = df.MeshFunction("size_t", mesh, dim=1, value=0)
leftBnd.mark(boundary_markers, clampedBndFlag)
rightBnd.mark(boundary_markers, loadBndFlag)

dx = df.Measure('dx', domain=mesh)
ds = df.Measure('ds', domain=mesh, subdomain_data=boundary_markers)

# %% [markdown]
# 4) **Spaces**

# %%
Uh = df.VectorFunctionSpace(mesh, "Lagrange", 1) # Unchanged
bcL = df.DirichletBC(Uh, df.Constant((0.0, 0.0)), boundary_markers, clampedBndFlag) # Unchanged

# Space for stresses and strains
Sh0 = df.VectorFunctionSpace(mesh, 'DG', degree = 0 , dim = 3)

# %% [markdown]
# 5) **Variational Formulation**: <br>
#
# - Strong format:
# $$
# \begin{cases}
# div \sigma = 0  \text{in} \, \Omega \\
# u = 0 \quad \text{on} \, \Gamma_1 \\
# \varepsilon = \nabla^s u \quad \text{in} \, \Omega \\
# \sigma  n  = t \quad \text{on} \, \Gamma_2 \\
# \end{cases}
# $$
# - DD equilibrium subproblem: Given $(\varepsilon^*, \sigma^*) \in Z_h$, solve for $(u,\eta) \in U_h$
# $$
# \begin{cases}
# (\mathbb{C} \nabla^s u , \nabla^s v ) = (\mathbb{C} \varepsilon^* , \nabla^s v ) \quad \forall v \in U_h, \\
# (\mathbb{C} \nabla^s \eta , \nabla^s \xi ) = \Pi_{ext}(\xi) - (\sigma^* , \nabla^s \xi ) \quad \forall \xi \in U_h \\
# \end{cases}
# $$
# - Updates:
# $$
# \begin{cases}
# \varepsilon = \nabla^s u \\
# \sigma = \sigma^* + \mathbb{C} \nabla^s \eta
# \end{cases}
# $$
# - DD ''bilinear'' form : $(\bullet , \nabla^s v)$ or sometimes  $(\mathbb{C} \nabla^s \bullet, \nabla^s v)$

# %%
from ddfenics.dd.ddbilinear import DDBilinear

# Unchanged
ty = -0.1
traction = df.Constant((0.0, ty))

u = df.TrialFunction(Uh) 
v = df.TestFunction(Uh)
b = df.inner(traction,v)*ds(loadBndFlag)

# replaces df.inner(sig(u) , df.grad(v))*dx
a = DDBilinear(ddmat, dx, u, v)

# %% [markdown]
# 6) **Statement and Solving the problem** <br>
# - DDProblem : States DD equilibrium subproblem and updates.
# - DDSolver : Implements the alternate minimization using SKlearn NearestNeighbors('ball_tree', ...) searchs for the projection onto data.
# - Stopping criteria: $\|d_k - d_{k-1}\|/energy$

# %%
from ddfenics.dd.ddfunction import DDFunction
from ddfenics.dd.ddmetric import DDMetric
from ddfenics.dd.ddproblem import DDProblem
from ddfenics.dd.ddsolver import DDSolver

# Extended solution : replaces u = df.Function(Uh)
sol = {"state_mech" : [ DDFunction(Sh0), DDFunction(Sh0)] , # mechanical states (eps, sig)
       "state_db": [ DDFunction(Sh0), DDFunction(Sh0)] ,  # database states (eps, sig)
       "u" : df.Function(Uh)} # displacemens

# DD global and local distance
dddist = DDMetric(ddmat.C, V = Sh0, dx = dx)

# replaces df.LinearVariationalProblem(a, b, uh, bcs = [bcL])
problem = DDProblem(a, b, sol, [bcL], metric = dddist) 

start = timer()

#replaces df.LinearVariationalSolver(problem)
solver = DDSolver(problem, opInit = 'random')

tol_ddcm = 1.0e-7
solver.solve(tol = tol_ddcm , maxit = 100);
end = timer()

uh = sol["u"]
normL2 = df.assemble(df.inner(uh,uh)*dx)

print("Time spent: ", end - start)
print("Norm L2: ", normL2)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# 	Inner Iteration #  1 ,- Relative Error =  5.261418e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.467672e-01
# 	Inner Iteration #  3 ,- Relative Error =  6.825556e-02
# 	Inner Iteration #  4 ,- Relative Error =  3.873329e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.305837e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.428833e-02
# 	Inner Iteration #  7 ,- Relative Error =  8.785507e-03
# 	Inner Iteration #  8 ,- Relative Error =  5.258920e-03
# 	Inner Iteration #  9 ,- Relative Error =  2.945300e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.687536e-03
# 	Inner Iteration # 11 ,- Relative Error =  1.012203e-03
# 	Inner Iteration # 12 ,- Relative Error =  6.303659e-04
# 	Inner Iteration # 13 ,- Relative Error =  3.991982e-04
# 	Inner Iteration # 14 ,- Relative Error =  2.668120e-04
# 	Inner Iteration # 15 ,- Relative Error =  9.635511e-05
# 	Inner Iteration # 16 ,- Relative Error =  1.910105e-05
# 	Inner Iteration # 17 ,- Relative Error =  0.000000e+00
# Time spent:  2.5804877800001123
# Norm L2:  0.0033018989233923927

# %% [markdown]
# 7) **Plotting**

# %% [markdown]
# a) *Minimisation*

# %%
hist = solver.hist

fig = plt.figure(1)
plt.title('Minimisation')
plt.plot(hist['relative_energy'], 'o-')
plt.xlabel('iterations')
plt.ylabel('energy')
plt.legend(loc = 'best')
plt.yscale('log')
plt.grid()

fig = plt.figure(2)
plt.title('Relative distance (wrt k-th iteration)')
plt.plot(hist['relative_distance'], 'o-', label = "relative_distance")
plt.plot([0,len(hist['relative_energy'])],[tol_ddcm,tol_ddcm], label = "threshold")
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('rel. distance')
plt.legend(loc = 'best')
plt.grid()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# b) *Data Convergence*

# %%
relative_norm = lambda x1, x0: np.sqrt(df.assemble( df.inner(x1 - x0, x1 - x0)*dx ) )/np.sqrt(df.assemble( df.inner(x0, x0)*dx ) )

Nd_list = [10,100, 1000, 10000, 50000, 100000] 
hist_list = []
error_u = []
error_eps = []
error_sig = []

sol_ref_file =  df.XDMFFile("bar_sol.xdmf")
sol_ref = {"state" : [DDFunction(Sh0), DDFunction(Sh0)], "u" : df.Function(Uh)}   
sol_ref_file.read_checkpoint(sol_ref["u"],"u")
sol_ref_file.read_checkpoint(sol_ref["state"][0],"eps")
sol_ref_file.read_checkpoint(sol_ref["state"][1],"sig")

np.random.seed(1)


for Nd_i in Nd_list:
    indexes = np.arange(0,Nd).astype('int')
    np.random.shuffle(indexes)
    DD_i = DD[indexes[:Nd_i], : , : ]
    ddmat_i = DDMaterial(DD_i, C = 100*np.diag([2.0,2.0,1.0]))
    
    a_i = DDBilinear(ddmat_i, dx, u, v) 

    sol_i = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
           "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
           "u" : df.Function(Uh)} # displacemens
    
    problem_i = DDProblem(a_i, b, sol_i, [bcL], metric = DDMetric(ddmat_i.C, V = Sh0, dx = dx)) 
    solver_i = DDSolver(problem_i, opInit = 'random', seed = 1)
    solver_i.solve(tol = tol_ddcm, maxit = 100)
    
    hist_list.append(copy.deepcopy(solver_i.hist))
    
    error_u.append(relative_norm(sol_i["u"], sol_ref["u"])) 
    error_eps.append(relative_norm(sol_i["state_mech"][0], sol_ref["state"][0])) 
    error_sig.append(relative_norm(sol_i["state_mech"][1], sol_ref["state"][1]))
    
    
    
plt.figure(5)
plt.title('Energy gap VS database size')
plt.plot(Nd_list, [hist_list[i]['relative_energy'][-1] for i in range(len(Nd_list))], '-o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Nd')
plt.ylabel('energy gap')
plt.grid()

plt.figure(6)
plt.title('Relative L2 errors VS database size (wrt classical solutions)')
plt.plot(Nd_list, error_u, '-o', label = 'u')
plt.plot(Nd_list, error_eps, '-o', label = 'eps')
plt.plot(Nd_list, error_sig, '-o', label = 'sig')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Nd')
plt.ylabel('Errors')
plt.legend(loc = 'best')
plt.grid()
# Out:
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  8.750577e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.890953e-02
# 	Inner Iteration #  3 ,- Relative Error =  1.667831e-02
# 	Inner Iteration #  4 ,- Relative Error =  4.924741e-03
# 	Inner Iteration #  5 ,- Relative Error =  8.773331e-04
# 	Inner Iteration #  6 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  7.355131e-01
# 	Inner Iteration #  2 ,- Relative Error =  8.487066e-02
# 	Inner Iteration #  3 ,- Relative Error =  2.826215e-02
# 	Inner Iteration #  4 ,- Relative Error =  1.247908e-02
# 	Inner Iteration #  5 ,- Relative Error =  3.786165e-03
# 	Inner Iteration #  6 ,- Relative Error =  2.721043e-03
# 	Inner Iteration #  7 ,- Relative Error =  2.894153e-03
# 	Inner Iteration #  8 ,- Relative Error =  2.094649e-03
# 	Inner Iteration #  9 ,- Relative Error =  1.210059e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.896902e-04
# 	Inner Iteration # 11 ,- Relative Error =  3.600001e-05
# 	Inner Iteration # 12 ,- Relative Error =  5.781797e-04
# 	Inner Iteration # 13 ,- Relative Error =  4.141861e-04
# 	Inner Iteration # 14 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  6.264635e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.168744e-01
# 	Inner Iteration #  3 ,- Relative Error =  4.470153e-02
# 	Inner Iteration #  4 ,- Relative Error =  2.388001e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.706974e-02
# 	Inner Iteration #  6 ,- Relative Error =  7.484540e-03
# 	Inner Iteration #  7 ,- Relative Error =  5.605581e-03
# 	Inner Iteration #  8 ,- Relative Error =  3.482974e-03
# 	Inner Iteration #  9 ,- Relative Error =  2.770232e-03
# 	Inner Iteration # 10 ,- Relative Error =  7.259382e-04
# 	Inner Iteration # 11 ,- Relative Error =  2.326632e-04
# 	Inner Iteration # 12 ,- Relative Error =  1.847987e-04
# 	Inner Iteration # 13 ,- Relative Error =  1.866233e-04
# 	Inner Iteration # 14 ,- Relative Error =  2.340463e-04
# 	Inner Iteration # 15 ,- Relative Error =  4.601802e-05
# 	Inner Iteration # 16 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  5.512239e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.361600e-01
# 	Inner Iteration #  3 ,- Relative Error =  6.209993e-02
# 	Inner Iteration #  4 ,- Relative Error =  3.401988e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.819076e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.138537e-02
# 	Inner Iteration #  7 ,- Relative Error =  6.007916e-03
# 	Inner Iteration #  8 ,- Relative Error =  2.921493e-03
# 	Inner Iteration #  9 ,- Relative Error =  2.589666e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.427766e-03
# 	Inner Iteration # 11 ,- Relative Error =  5.249055e-04
# 	Inner Iteration # 12 ,- Relative Error =  1.835021e-04
# 	Inner Iteration # 13 ,- Relative Error =  7.513095e-05
# 	Inner Iteration # 14 ,- Relative Error =  2.948851e-05
# 	Inner Iteration # 15 ,- Relative Error =  8.866837e-05
# 	Inner Iteration # 16 ,- Relative Error =  1.411367e-04
# 	Inner Iteration # 17 ,- Relative Error =  5.608497e-05
# 	Inner Iteration # 18 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  5.304418e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.449045e-01
# 	Inner Iteration #  3 ,- Relative Error =  6.764227e-02
# 	Inner Iteration #  4 ,- Relative Error =  3.805514e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.192202e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.357237e-02
# 	Inner Iteration #  7 ,- Relative Error =  8.188360e-03
# 	Inner Iteration #  8 ,- Relative Error =  4.649730e-03
# 	Inner Iteration #  9 ,- Relative Error =  2.742561e-03
# 	Inner Iteration # 10 ,- Relative Error =  2.026487e-03
# 	Inner Iteration # 11 ,- Relative Error =  8.819668e-04
# 	Inner Iteration # 12 ,- Relative Error =  6.510175e-04
# 	Inner Iteration # 13 ,- Relative Error =  2.220876e-04
# 	Inner Iteration # 14 ,- Relative Error =  9.628983e-05
# 	Inner Iteration # 15 ,- Relative Error =  1.374929e-04
# 	Inner Iteration # 16 ,- Relative Error =  2.032599e-05
# 	Inner Iteration # 17 ,- Relative Error =  5.852472e-05
# 	Inner Iteration # 18 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  5.261418e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.467672e-01
# 	Inner Iteration #  3 ,- Relative Error =  6.825556e-02
# 	Inner Iteration #  4 ,- Relative Error =  3.873329e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.305837e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.428833e-02
# 	Inner Iteration #  7 ,- Relative Error =  8.785507e-03
# 	Inner Iteration #  8 ,- Relative Error =  5.258920e-03
# 	Inner Iteration #  9 ,- Relative Error =  2.945300e-03
# 	Inner Iteration # 10 ,- Relative Error =  1.687536e-03
# 	Inner Iteration # 11 ,- Relative Error =  1.012203e-03
# 	Inner Iteration # 12 ,- Relative Error =  6.303659e-04
# 	Inner Iteration # 13 ,- Relative Error =  3.991982e-04
# 	Inner Iteration # 14 ,- Relative Error =  2.668120e-04
# 	Inner Iteration # 15 ,- Relative Error =  9.635511e-05
# 	Inner Iteration # 16 ,- Relative Error =  1.910105e-05
# 	Inner Iteration # 17 ,- Relative Error =  0.000000e+00

# %% [markdown]
# 8. **Sanity check:** : Recovering reference database

# %%
from ddfenics.dd.ddfunction import DDFunction


data = np.concatenate((sol_ref["state"][0].vector().get_local().reshape((-1,3)), 
                       sol_ref["state"][1].vector().get_local().reshape((-1,3))), axis = 1)

print(data.shape)
print(np.min(data[:,:3], axis = 0) )
print(np.max(data[:,:3], axis = 0) )

np.savetxt('database_ref.txt', data, header = '1.0 \n%d 2 3 3'%data.shape[0], comments = '', fmt='%.8e')
ddmat = DDMaterial('database_ref.txt') 
ddmat.plotDB()
# Out:
# (1000, 6)
# [-0.02294876 -0.00840356 -0.00677863]
# [0.02294876 0.00840356 0.0011281 ]
# shuffling
