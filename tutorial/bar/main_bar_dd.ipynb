# %% [markdown]
# 0) **Imports**

# %%
import os, sys
from timeit import default_timer as timer
import dolfin as df # Fenics : dolfin + ufl + FIAT + ...
import numpy as np
import matplotlib.pyplot as plt
import copy 

# DDfenics imports
from ddfenics.dd.ddmaterial import DDMaterial 
from ddfenics.dd.ddmetric import DDMetric
from ddfenics.dd.ddfunction import DDFunction
from ddfenics.dd.ddbilinear import DDBilinear
from ddfenics.dd.ddproblem import DDProblem
from ddfenics.dd.ddsolver import DDSolver

# %% [markdown]
# 1) **Consititutive behaviour Definition**

# %% [markdown]
# 2) **Mesh** (Unchanged)

# %%
# fetricks is a set of utilitary functions to facilitate our lives
# from fetricks import symgrad_mandel
from fetricks.mechanics.elasticity_conversions import youngPoisson2lame
database_file = 'database_generated.txt' # previous computed

Nd = 100000 # number of points

E = 100.0
nu = 0.3
lamb, mu = youngPoisson2lame(nu, E) 
print(lamb,mu)

Cmat = np.array( [[lamb + 2*mu, lamb, 0], [lamb, lamb + 2*mu, 0], [0, 0, 2*mu]] )

np.random.seed(1)

eps_range = np.array([[-0.03,0.03], [-0.009, 0.009], [-0.012, 0.002]]).T
DD = np.zeros((Nd,2,3))

for i in range(Nd):
    DD[i,0,:] = eps_range[0,:] + np.random.rand(3)*(eps_range[1,:] - eps_range[0,:])
    DD[i,1,:] = Cmat@DD[i,0,:]
    
np.savetxt(database_file, DD.reshape((-1,6)), header = '1.0 \n%d 2 3 3'%Nd, comments = '', fmt='%.8e', )

ddmat = DDMaterial(database_file)  # replaces sigma_law = lambda u : ...

print(Cmat)
ddmat.estimateC()
print(ddmat.C)
print(ddmat.grad)

ddmat.plotDB()
# Out:
# 57.69230769230769 38.46153846153846
# shuffling
# [[134.61538462  57.69230769   0.        ]
#  [ 57.69230769 134.61538462   0.        ]
#  [  0.           0.          76.92307692]]
# [[1.34615385e+02 5.76923077e+01 4.53622633e-10]
#  [5.76923077e+01 1.34615385e+02 4.43756581e-10]
#  [4.53622633e-10 4.43756581e-10 7.69230769e+01]]
# <function symgrad_mandel at 0x7fe8a3c68a60>

# %%
Nx =  100 # x10
Ny =  30 # x10
Lx = 2.0
Ly = 0.5
mesh = df.RectangleMesh(df.Point(0.0,0.0) , df.Point(Lx,Ly), Nx, Ny, 'left/right');
df.plot(mesh);

# %% [markdown]
# 3) **Mesh regions** (Unchanged)

# %%
leftBnd = df.CompiledSubDomain('near(x[0], 0.0) && on_boundary')
rightBnd = df.CompiledSubDomain('near(x[0], Lx) && on_boundary', Lx=Lx)

clampedBndFlag = 1
loadBndFlag = 2
boundary_markers = df.MeshFunction("size_t", mesh, dim=1, value=0)
leftBnd.mark(boundary_markers, clampedBndFlag)
rightBnd.mark(boundary_markers, loadBndFlag)

dx = df.Measure('dx', domain=mesh)
ds = df.Measure('ds', domain=mesh, subdomain_data=boundary_markers)

# %% [markdown]
# 4) **Spaces**

# %%
Uh = df.VectorFunctionSpace(mesh, "Lagrange", 1) # Unchanged
bcL = df.DirichletBC(Uh, df.Constant((0.0, 0.0)), boundary_markers, clampedBndFlag) # Unchanged

# Space for stresses and strains
Sh0 = df.VectorFunctionSpace(mesh, 'DG', degree = 0 , dim = 3)

# %% [markdown]
# 5) **Variational Formulation**: <br>
#
# - Strong format:
# $$
# \begin{cases}
# div \sigma = 0  \text{in} \, \Omega \\
# u = 0 \quad \text{on} \, \Gamma_1 \\
# \varepsilon = \nabla^s u \quad \text{in} \, \Omega \\
# \sigma  n  = t \quad \text{on} \, \Gamma_2 \\
# \end{cases}
# $$
# - DD equilibrium subproblem: Given $(\varepsilon^*, \sigma^*) \in Z_h$, solve for $(u,\eta) \in U_h$
# $$
# \begin{cases}
# (\mathbb{C} \nabla^s u , \nabla^s v ) = (\mathbb{C} \varepsilon^* , \nabla^s v ) \quad \forall v \in U_h, \\
# (\mathbb{C} \nabla^s \eta , \nabla^s \xi ) = \Pi_{ext}(\xi) - (\sigma^* , \nabla^s \xi ) \quad \forall \xi \in U_h \\
# \end{cases}
# $$
# - Updates:
# $$
# \begin{cases}
# \varepsilon = \nabla^s u \\
# \sigma = \sigma^* + \mathbb{C} \nabla^s \eta
# \end{cases}
# $$
# - DD ''bilinear'' form : $(\bullet , \nabla^s v)$ or sometimes  $(\mathbb{C} \nabla^s \bullet, \nabla^s v)$

# %%
# Unchanged
ty = -0.1
traction = df.Constant((0.0, ty))

u = df.TrialFunction(Uh) 
v = df.TestFunction(Uh)
b = df.inner(traction,v)*ds(loadBndFlag)

a = DDBilinear(ddmat, dx, u, v) # replaces df.inner(sig(u) , df.grad(v))*dx

# %% [markdown]
# 6) **Statement and Solving the problem** <br>
# - DDProblem : States DD equilibrium subproblem and updates.
# - DDSolver : Implements the alternate minimization using SKlearn NearestNeighbors('ball_tree', ...) searchs for the projection onto data.
# - Stopping criteria: $\|d_k - d_{k-1}\|/energy$

# %%
# Extended solution : replaces u = df.Function(Uh)
sol = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
       "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
       "u" : df.Function(Uh)} # displacemens

# replaces df.LinearVariationalProblem(a, b, uh, bcs = [bcL])
problem = DDProblem(a, b, sol, [bcL], metric = DDMetric(ddmat.C, V = Sh0, dx = dx)) 

start = timer()
#replaces df.LinearVariationalSolver(problem)
solver = DDSolver(problem, opInit = 'random', seed = 1)
tol = 1e-7
hist = solver.solve(tol = tol, maxit = 100);

end = timer()

uh = sol["u"]
normL2 = df.assemble(df.inner(uh,uh)*dx)
normL2_ref = 0.00046895042573293067

print("Time spent: ", end - start)
print("Norm L2: ", normL2)
print("Norm L2 (Ref)",  normL2_ref)
print("Relative Error",  np.abs(normL2_ref - normL2)/normL2_ref)
# Out:
# 	Inner Iteration #  1 ,- Relative Error =  7.092680e-01
# 	Inner Iteration #  2 ,- Relative Error =  3.125309e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.373366e-01
# 	Inner Iteration #  4 ,- Relative Error =  5.974976e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.258232e-02
# 	Inner Iteration #  6 ,- Relative Error =  7.100670e-03
# 	Inner Iteration #  7 ,- Relative Error =  1.046939e-03
# 	Inner Iteration #  8 ,- Relative Error =  4.955453e-05
# 	Inner Iteration #  9 ,- Relative Error =  9.428397e-07
# 	Inner Iteration # 10 ,- Relative Error =  0.000000e+00
# Time spent:  1.2706735909996496
# Norm L2:  0.0033359218778807836
# Norm L2 (Ref) 0.00046895042573293067
# Relative Error 6.113591746221392

# %% [markdown]
# 7) **Postprocessing**

# %% [markdown]
# a) *Convergence*

# %%
hist = solver.hist

fig = plt.figure(1)
plt.title('d_conv = {0}'.format(hist['distance'][-1]))
plt.plot(hist['distance'], 'o-', label = "distance")
plt.xlabel('iterations')
plt.ylabel('distance')
plt.legend(loc = 'best')
plt.grid()

fig = plt.figure(2)
plt.title('d_conv = {0}'.format(hist['relative_energy'][-1]))
plt.plot(hist['relative_distance'], 'o-', label = "relative_distance")
plt.plot(hist['classical_relative_energy'], 'o-' , label = "classical_relative_energy")
plt.plot([0,len(hist['relative_energy'])],[tol,tol])
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('distance')
plt.legend(loc = 'best')
plt.grid()

# %% [markdown]
# c) *Pos-Processing*

# %%
import fetricks.fenics.postprocessing.wrapper_io as iofe
from fetricks.fenics.la.wrapper_solvers import local_project

uh.rename('uh', '')
state_mech[1].rename('sigma_mech', '')
state_db[1].rename('sigma_db', '')

iofe.exportXDMF_gen("bar_dd.xdmf" , {'vertex': [uh], 'cell': [state_mech[1], state_db[1]]})

# %%
Nd_list = [10,100, 1000, 10000, 50000, 100000] 
hist_list = []
for Nd_i in Nd_list:
    indexes = np.arange(0,Nd).astype('int')
    np.random.shuffle(indexes)
    DD_i = DD[indexes[:Nd_i], : , : ]
    ddmat_i = DDMaterial(DD_i)
    
    a_i = DDBilinear(ddmat_i, dx, u, v) # replaces df.inner(sig(u) , df.grad(v))*dx

    sol_i = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
           "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
           "u" : df.Function(Uh)} # displacemens
    
    # replaces df.LinearVariationalProblem(a, b, uh, bcs = [bcL])
    problem_i = DDProblem(a_i, b, sol_i, [bcL], metric = DDMetric(ddmat_i.C, V = Sh0, dx = dx)) 
    solver_i = DDSolver(problem_i, opInit = 'zero', seed = 1)
    solver_i.solve(tol = tol, maxit = 100)
    
    hist_list.append(copy.deepcopy(solver_i.hist))
    
    
plt.figure(5)
plt.plot(Nd_list, [hist_list[i]['relative_energy'][-1] for i in range(len(Nd_list))], '-o')
plt.xscale('log')
plt.yscale('log')
plt.grid()
# Out:
# shuffling
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# 	Inner Iteration #  1 ,- Relative Error =  9.469168e-01
# 	Inner Iteration #  2 ,- Relative Error =  5.399943e-02
# 	Inner Iteration #  3 ,- Relative Error =  1.028585e-03
# 	Inner Iteration #  4 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  8.442434e-01
# 	Inner Iteration #  2 ,- Relative Error =  1.939005e-01
# 	Inner Iteration #  3 ,- Relative Error =  5.351214e-02
# 	Inner Iteration #  4 ,- Relative Error =  4.952993e-03
# 	Inner Iteration #  5 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  7.578673e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.703799e-01
# 	Inner Iteration #  3 ,- Relative Error =  8.451169e-02
# 	Inner Iteration #  4 ,- Relative Error =  2.301924e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.569904e-03
# 	Inner Iteration #  6 ,- Relative Error =  8.587541e-05
# 	Inner Iteration #  7 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  7.156735e-01
# 	Inner Iteration #  2 ,- Relative Error =  3.027328e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.280744e-01
# 	Inner Iteration #  4 ,- Relative Error =  4.933084e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.328937e-02
# 	Inner Iteration #  6 ,- Relative Error =  1.645314e-03
# 	Inner Iteration #  7 ,- Relative Error =  7.047522e-05
# 	Inner Iteration #  8 ,- Relative Error =  3.707750e-06
# 	Inner Iteration #  9 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  7.105146e-01
# 	Inner Iteration #  2 ,- Relative Error =  3.097244e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.348291e-01
# 	Inner Iteration #  4 ,- Relative Error =  5.765510e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.996199e-02
# 	Inner Iteration #  6 ,- Relative Error =  5.347409e-03
# 	Inner Iteration #  7 ,- Relative Error =  5.917104e-04
# 	Inner Iteration #  8 ,- Relative Error =  6.889430e-06
# 	Inner Iteration #  9 ,- Relative Error =  0.000000e+00
# shuffling
# 	Inner Iteration #  1 ,- Relative Error =  7.092680e-01
# 	Inner Iteration #  2 ,- Relative Error =  3.125309e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.373366e-01
# 	Inner Iteration #  4 ,- Relative Error =  5.974976e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.258232e-02
# 	Inner Iteration #  6 ,- Relative Error =  7.100671e-03
# 	Inner Iteration #  7 ,- Relative Error =  1.046939e-03
# 	Inner Iteration #  8 ,- Relative Error =  4.955453e-05
# 	Inner Iteration #  9 ,- Relative Error =  9.428398e-07
# 	Inner Iteration # 10 ,- Relative Error =  0.000000e+00
