# %% [markdown]
# 0) **Imports**

# %%
import os, sys
from timeit import default_timer as timer
import dolfin as df # Fenics : dolfin + ufl + FIAT + ...
import numpy as np
import matplotlib.pyplot as plt

# fetricks is a set of utilitary functions to facilitate our lives
from fetricks.mechanics.elasticity_conversions import youngPoisson2lame
from fetricks import symgrad_mandel

# DDfenics imports
from ddfenics.dd.ddmaterial import DDMaterial 
from ddfenics.dd.ddmetric import DDMetric
from ddfenics.dd.ddfunction import DDFunction
from ddfenics.dd.ddbilinear import DDBilinear
from ddfenics.dd.ddproblem import DDProblem
from ddfenics.dd.ddsolver import DDSolver

# %% [markdown]
# 1) **Consititutive behaviour Definition**

# %%
database_file = 'database_ref.txt' # previous computed

metric = {'YOUNG_MODULUS': 100.0,
          'POISSON_RATIO': 0.3}
lamb, mu = youngPoisson2lame(metric['POISSON_RATIO'], metric['YOUNG_MODULUS']) 

Cmat = np.array( [[lamb + 2*mu, lamb, 0], [lamb, lamb + 2*mu, 0], [0, 0, 2*mu]] )

ddmat = DDMaterial(database_file, Cmat)  # replaces sigma_law = lambda u : ...
print(ddmat.C)
ddmat.estimateC()
print(ddmat.C)
print(ddmat.grad)

ddmat.plotDB()
# Out:
# shuffling
# [[134.61538462  57.69230769   0.        ]
#  [ 57.69230769 134.61538462   0.        ]
#  [  0.           0.          76.92307692]]
# [[3.84305738e+02 1.56426217e+02 2.67929988e-11]
#  [1.56426217e+02 4.65982492e+02 1.29951279e-10]
#  [2.67929988e-11 1.29951279e-10 1.26672726e+02]]
# <function symgrad_mandel at 0x7f8cf921ec10>

# %% [markdown]
# 2) **Mesh** (Unchanged)

# %%
Nx =  10 # x10
Ny =  5 # x10
Lx = 2.0
Ly = 0.5
mesh = df.RectangleMesh(df.Point(0.0,0.0) , df.Point(Lx,Ly), Nx, Ny, 'left/right');
df.plot(mesh);

# %% [markdown]
# 3) **Mesh regions** (Unchanged)

# %%
leftBnd = df.CompiledSubDomain('near(x[0], 0.0) && on_boundary')
rightBnd = df.CompiledSubDomain('near(x[0], Lx) && on_boundary', Lx=Lx)

clampedBndFlag = 1
loadBndFlag = 2
boundary_markers = df.MeshFunction("size_t", mesh, dim=1, value=0)
leftBnd.mark(boundary_markers, clampedBndFlag)
rightBnd.mark(boundary_markers, loadBndFlag)

dx = df.Measure('dx', domain=mesh)
ds = df.Measure('ds', domain=mesh, subdomain_data=boundary_markers)

# %% [markdown]
# 4) **Spaces**

# %%
Uh = df.VectorFunctionSpace(mesh, "Lagrange", 1) # Unchanged
bcL = df.DirichletBC(Uh, df.Constant((0.0, 0.0)), boundary_markers, clampedBndFlag) # Unchanged

# Space for stresses and strains
Sh0 = df.VectorFunctionSpace(mesh, 'DG', degree = 0 , dim = 3)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %% [markdown]
# 5) **Variational Formulation**: <br>
#
# - Strong format:
# $$
# \begin{cases}
# div \sigma = 0 \quad \text{in} \, \Omega \\
# u = 0 \quad \text{on} \, \Gamma_1 \\
# \varepsilon = \nabla^s u \quad \text{in} \, \Omega \\
# \sigma  n  = t \quad \text{on} \, \Gamma_2 \\
# \end{cases}
# $$
# - DD equilibrium subproblem: Given $(\varepsilon^*, \sigma^*) \in Z_h$, solve for $(u,\eta) \in U_h$
# $$
# \begin{cases}
# (\mathbb{C} \nabla^s u , \nabla^s v ) = (\mathbb{C} \varepsilon^* , \nabla^s v ) \quad \forall v \in U_h, \\
# (\mathbb{C} \nabla^s \eta , \nabla^s \xi ) = \Pi_{ext}(\xi) - (\sigma^* , \nabla^s \xi ) \quad \forall \xi \in U_h \\
# \end{cases}
# $$
# - Updates:
# $$
# \begin{cases}
# \varepsilon = \nabla^s u \\
# \sigma = \sigma^* + \mathbb{C} \nabla^s \eta
# \end{cases}
# $$
# - DD ''bilinear'' form : $(\bullet , \nabla^s v)$ or sometimes  $(\mathbb{C} \nabla^s \bullet, \nabla^s v)$

# %%
# Unchanged
ty = -0.1
traction = df.Constant((0.0, ty))

u = df.TrialFunction(Uh) 
v = df.TestFunction(Uh)
b = df.inner(traction,v)*ds(loadBndFlag)

a = DDBilinear(ddmat, dx, u, v) # replaces df.inner(sig(u) , df.grad(v))*dx

# %% [markdown]
# 6) **Statement and Solving the problem** <br>
# - DDProblem : States DD equilibrium subproblem and updates.
# - DDSolver : Implements the alternate minimization using SKlearn NearestNeighbors('ball_tree', ...) searchs for the projection onto data.
# - Stopping criteria: $\|d_k - d_{k-1}\|/energy$

# %%
# Extended solution : replaces u = df.Function(Uh)
sol = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
       "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
       "u" : df.Function(Uh)} # displacemens

# replaces df.LinearVariationalProblem(a, b, uh, bcs = [bcL])
problem = DDProblem(a, b, sol, [bcL], metric = DDMetric(ddmat.C, V = Sh0, dx = dx)) 

start = timer()
#replaces df.LinearVariationalSolver(problem)
solver = DDSolver(problem, opInit = 'random', seed = 1)
tol = 1e-7
hist = solver.solve(tol = tol, maxit = 100);

end = timer()

uh = sol["u"]
normL2 = df.assemble(df.inner(uh,uh)*dx)
normL2_ref = 0.00046895042573293067

print("Time spent: ", end - start)
print("Norm L2: ", normL2)
print("Norm L2 (Ref)",  normL2_ref)
print("Relative Error",  np.abs(normL2_ref - normL2)/normL2_ref)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# 	Inner Iteration #  1 ,- Relative Error =  8.729983e-01
# 	Inner Iteration #  2 ,- Relative Error =  2.996936e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.669670e-01
# 	Inner Iteration #  4 ,- Relative Error =  6.197235e-02
# 	Inner Iteration #  5 ,- Relative Error =  1.883830e-02
# 	Inner Iteration #  6 ,- Relative Error =  5.780455e-03
# 	Inner Iteration #  7 ,- Relative Error =  2.230487e-03
# 	Inner Iteration #  8 ,- Relative Error =  7.323363e-04
# 	Inner Iteration #  9 ,- Relative Error =  3.265656e-04
# 	Inner Iteration # 10 ,- Relative Error =  2.495250e-04
# 	Inner Iteration # 11 ,- Relative Error =  9.205561e-05
# 	Inner Iteration # 12 ,- Relative Error =  8.933966e-06
# 	Inner Iteration # 13 ,- Relative Error =  2.708373e-06
# 	Inner Iteration # 14 ,- Relative Error =  4.201900e-06
# 	Inner Iteration # 15 ,- Relative Error =  0.000000e+00
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Time spent:  7.543361729000026
# Norm L2:  0.00030240376181605666
# Norm L2 (Ref) 0.00046895042573293067
# Relative Error 0.35514769744920344

# %% [markdown]
# 7) **Playing around**

# %% [markdown]
# a) *Convergence*

# %%
hist = solver.hist

fig = plt.figure(1)
plt.title('d_conv = {0}'.format(hist['distance'][-1]))
plt.plot(hist['distance'], 'o-', label = "distance")
plt.xlabel('iterations')
plt.ylabel('distance')
plt.legend(loc = 'best')
plt.grid()

fig = plt.figure(2)
plt.title('d_conv = {0}'.format(hist['relative_energy'][-1]))
plt.plot(hist['relative_distance'], 'o-', label = "relative_distance")
plt.plot(hist['classical_relative_energy'], 'o-' , label = "classical_relative_energy")
plt.plot([0,len(hist['relative_energy'])],[tol,tol])
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('distance')
plt.legend(loc = 'best')
plt.grid()

# %% [markdown]
# b) *Scatter*

# %%
state_mech = sol["state_mech"]
state_db = sol["state_db"]

fig,(ax1,ax2) = plt.subplots(1,2)
ax1.set_xlabel(r'$\epsilon_{xx}+\epsilon_{yy}$')
ax1.set_ylabel(r'$\sigma_{xx}+\sigma_{yy}$')
ax1.scatter(ddmat.DB[:, 0, 0] + ddmat.DB[:, 0, 1], ddmat.DB[:, 1, 0] + ddmat.DB[:, 1, 1], c='gray')
ax1.scatter(state_db[0].data()[:,0]+state_db[0].data()[:,1],state_db[1].data()[:,0]+state_db[1].data()[:,1], c='blue')
ax1.scatter(state_mech[0].data()[:,0]+state_mech[0].data()[:,1],state_mech[1].data()[:,0]+state_mech[1].data()[:,1], marker = 'x', c='black' )

ax2.set_xlabel(r'$\epsilon_{xy}$')
ax2.set_ylabel(r'$\sigma_{xy}$')
ax2.scatter(ddmat.DB[:, 0, 2], ddmat.DB[:, 1, 2], c='gray')
ax2.scatter(state_db[0].data()[:,2], state_db[1].data()[:,2], c='blue')
ax2.scatter(state_mech[0].data()[:,2], state_mech[1].data()[:,2], marker = 'x', c='black')

# %% [markdown]
# c) *Pos-Processing*

# %%
import fetricks.fenics.postprocessing.wrapper_io as iofe
from fetricks.fenics.la.wrapper_solvers import local_project

uh.rename('uh', '')
state_mech[1].rename('sigma_mech', '')
state_db[1].rename('sigma_db', '')

iofe.exportXDMF_gen("bar_dd.xdmf" , {'vertex': [uh], 'cell': [state_mech[1], state_db[1]]})
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# terminate called after throwing an instance of 'XdmfError'
#   what():  ':' not found in content generateHeavyControllers in XdmfCoreItemFactory -- double check an HDF5 data set is specified for the file
#
# Loguru caught a signal: SIGABRT
# Stack trace:
# 59      0x561ca00a13f5 paraview(+0xd3f5) [0x561ca00a13f5]
# 58      0x7ff8c2093e40 __libc_start_main + 128
# 57      0x7ff8c2093d90 /usr/bin/../lib/x86_64-linux-gnu/libc.so.6(+0x29d90) [0x7ff8c2093d90]
# 56      0x561ca00a00a3 paraview(+0xc0a3) [0x561ca00a00a3]
# 55      0x7ff8c07d9ce4 QCoreApplication::exec() + 148
# 54      0x7ff8c07d174b QEventLoop::exec(QFlags<QEventLoop::ProcessEventsFlag>) + 299
# 53      0x7ff8c082c0a8 QEventDispatcherGlib::processEvents(QFlags<QEventLoop::ProcessEventsFlag>) + 104
# 52      0x7ff8bb7ee3c3 g_main_context_iteration + 51
# 51      0x7ff8bb8456f8 /lib/x86_64-linux-gnu/libglib-2.0.so.0(+0xaa6f8) [0x7ff8bb8456f8]
# 50      0x7ff8bb7f0d1b g_main_context_dispatch + 619
# 49      0x7ff8c082bd24 /usr/bin/../lib/x86_64-linux-gnu/libQt5Core.so.5(+0x312d24) [0x7ff8c082bd24]
# 48      0x7ff8c082b3db QTimerInfoList::activateTimers() + 987
# 47      0x7ff8c07d2e2a QCoreApplication::notifyInternal2(QObject*, QEvent*) + 314
# 46      0x7ff8c1845713 QApplicationPrivate::notify_helper(QObject*, QEvent*) + 131
# 45      0x7ff8c080032f QObject::event(QEvent*) + 463
# 44      0x7ff8c080e7ee QTimer::timeout(QTimer::QPrivateSignal) + 62
# 43      0x7ff8c080a7b8 /usr/bin/../lib/x86_64-linux-gnu/libQt5Core.so.5(+0x2f17b8) [0x7ff8c080a7b8]
# 42      0x7ff8c1ec1217 pqCommandLineOptionsBehavior::processCommandLineOptions() + 23
# 41      0x7ff8c1ec0559 pqCommandLineOptionsBehavior::processData() + 1081
# 40      0x7ff8c1f04c05 pqLoadDataReaction::loadData(QStringList const&, QString const&, QString const&, pqServer*) + 613
# 39      0x7ff8c1f031d9 pqLoadDataReaction::loadData(QList<QStringList> const&, QString const&, QString const&, pqServer*) + 841
# 38      0x7ff8c1effb57 pqLoadDataReaction::LoadFile(QStringList const&, pqServer*, QPair<QString, QString> const&) + 71
# 37      0x7ff8c1259f93 pqObjectBuilder::createReader(QString const&, QString const&, QStringList const&, pqServer*) + 1155
# 36      0x7ff8c1255381 /usr/bin/../lib/x86_64-linux-gnu/libpqCore-pv5.10.so.1(+0xff381) [0x7ff8c1255381]
# 35      0x7ff8be262644 vtkSMParaViewPipelineControllerWithRendering::PostInitializeProxy(vtkSMProxy*) + 68
# 34      0x7ff8c032bb31 vtkSMParaViewPipelineController::PostInitializeProxy(vtkSMProxy*) + 385
# 33      0x7ff8c0395e11 vtkSMSourceProxy::UpdatePipelineInformation() + 129
# 32      0x7ff8c028e49a vtkPVSessionBase::ExecuteStream(unsigned int, vtkClientServerStream const&, bool) + 122
# 31      0x7ff8c0297a2b vtkPVSessionCore::ExecuteStreamInternal(vtkClientServerStream const&, bool) + 251
# 30      0x7ff8be04c4e5 vtkClientServerInterpreter::ProcessStream(vtkClientServerStream const&) + 37
# 29      0x7ff8be04c01d vtkClientServerInterpreter::ProcessOneMessage(vtkClientServerStream const&, int) + 237
# 28      0x7ff8be04b8cd vtkClientServerInterpreter::ProcessCommandInvoke(vtkClientServerStream const&, int) + 1197
# 27      0x7ff8be8b6240 vtkSISourceProxyCommand(vtkClientServerInterpreter*, vtkObjectBase*, char const*, vtkClientServerStream const&, vtkClientServerStream&, void*) + 1776
# 26      0x7ff8c02c1e70 vtkSISourceProxy::UpdatePipelineInformation() + 176
# 25      0x7ff8bc1b6c9a vtkDemandDrivenPipeline::UpdateInformation() + 42
# 24      0x7ff8bc1b58c4 vtkDemandDrivenPipeline::ProcessRequest(vtkInformation*, vtkInformationVector**, vtkInformationVector*) + 612
# 23      0x7ff8bc1a6417 vtkCompositeDataPipeline::ExecuteDataObject(vtkInformation*, vtkInformationVector**, vtkInformationVector*) + 87
# 22      0x7ff8bc1b2624 vtkExecutive::CallAlgorithm(vtkInformation*, int, vtkInformationVector**, vtkInformationVector*) + 84
# 21      0x7ff8ba2aeb56 vtkXdmf3Reader::RequestDataObjectInternal(vtkInformationVector*) + 726
# 20      0x7ff8ba2ae1c8 /usr/bin/../lib/x86_64-linux-gnu/libvtkIOXdmf3-pv5.10.so.1(+0x3e1c8) [0x7ff8ba2ae1c8]
# 19      0x7ff8b44aacc2 XdmfReader::read(std::string const&) const + 34
# 18      0x7ff8b43b4dec XdmfCoreReader::read(std::string const&) const + 44
# 17      0x7ff8b43b93dd XdmfCoreReader::readItems(std::string const&) const + 557
# 16      0x7ff8b43b6a46 /usr/bin/../lib/x86_64-linux-gnu/libvtkxdmfcore-pv5.10.so.1(+0x71a46) [0x7ff8b43b6a46]
# 15      0x7ff8b43b6a46 /usr/bin/../lib/x86_64-linux-gnu/libvtkxdmfcore-pv5.10.so.1(+0x71a46) [0x7ff8b43b6a46]
# 14      0x7ff8b43b6a46 /usr/bin/../lib/x86_64-linux-gnu/libvtkxdmfcore-pv5.10.so.1(+0x71a46) [0x7ff8b43b6a46]
# 13      0x7ff8b43b6a46 /usr/bin/../lib/x86_64-linux-gnu/libvtkxdmfcore-pv5.10.so.1(+0x71a46) [0x7ff8b43b6a46]
# 12      0x7ff8b43b6ad5 /usr/bin/../lib/x86_64-linux-gnu/libvtkxdmfcore-pv5.10.so.1(+0x71ad5) [0x7ff8b43b6ad5]
# 11      0x7ff8b4382edd XdmfArray::populateItem(std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string > > > const&, std::vector<boost::shared_ptr<XdmfItem>, std::allocator<boost::shared_ptr<XdmfItem> > > const&, XdmfCoreReader const*) + 2701
# 10      0x7ff8b43b4d3c XdmfCoreReader::generateHeavyDataControllers(std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string > > >, std::vector<unsigned int > const&, boost::shared_ptr<XdmfArrayType const>, std::string const&) const + 76
# 9       0x7ff8b43be7b3 XdmfCoreItemFactory::generateHeavyDataControllers(std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string > > > const&, std::vector<unsigned int > const&, boost::shared_ptr<XdmfArrayType const>, std::string const&) const + 10019
# 8       0x7ff8b436cb4c /usr/bin/../lib/x86_64-linux-gnu/libvtkxdmfcore-pv5.10.so.1(+0x27b4c) [0x7ff8b436cb4c]
# 7       0x7ff8bf845518 /usr/bin/../lib/x86_64-linux-gnu/libstdc++.so.6(+0xae518) [0x7ff8bf845518]
# 6       0x7ff8bf8452b7 /usr/bin/../lib/x86_64-linux-gnu/libstdc++.so.6(+0xae2b7) [0x7ff8bf8452b7]
# 5       0x7ff8bf84524c /usr/bin/../lib/x86_64-linux-gnu/libstdc++.so.6(+0xae24c) [0x7ff8bf84524c]
# 4       0x7ff8bf839bbe /usr/bin/../lib/x86_64-linux-gnu/libstdc++.so.6(+0xa2bbe) [0x7ff8bf839bbe]
# 3       0x7ff8c20927f3 abort + 211
# 2       0x7ff8c20ac476 raise + 22
# 1       0x7ff8c2100a7c pthread_kill + 300
# 0       0x7ff8c20ac520 /usr/bin/../lib/x86_64-linux-gnu/libc.so.6(+0x42520) [0x7ff8c20ac520]
# (   6.576s) [paraview        ]                       :0     FATL| Signal: SIGABRT
# Aborted (core dumped)
# 34304

# %% [markdown]
# d) Less Data

# %%
ddmat = DDMaterial(ddmat.DB[:1000], Cmat)  # replaces sigma_law = lambda u : ...
ddmat.estimateC()

ddmat.plotDB()

print(ddmat.DB.shape)
# Out:
# shuffling
# (1001, 2, 3)

# %%
a = DDBilinear(ddmat, dx, u, v) # replaces df.inner(sig(u) , df.grad(v))*dx

sol = {"state_mech" : [DDFunction(Sh0), DDFunction(Sh0)], # mechanical states (eps, sig)
       "state_db": [DDFunction(Sh0), DDFunction(Sh0)],  # database states (eps, sig)
       "u" : df.Function(Uh)} # displacemens

problem = DDProblem(a, b, sol, [bcL], metric = DDMetric(ddmat.C, V = Sh0, dx = dx)) 

solver = DDSolver(problem, opInit = 'zero', seed = 1)
tol = 1e-7
hist = solver.solve(tol = tol, maxit = 100);
# Out:
# 	Inner Iteration #  1 ,- Relative Error =  8.682148e-01
# 	Inner Iteration #  2 ,- Relative Error =  3.020973e-01
# 	Inner Iteration #  3 ,- Relative Error =  1.569949e-01
# 	Inner Iteration #  4 ,- Relative Error =  5.635343e-02
# 	Inner Iteration #  5 ,- Relative Error =  2.034711e-02
# 	Inner Iteration #  6 ,- Relative Error =  5.871496e-03
# 	Inner Iteration #  7 ,- Relative Error =  1.473539e-03
# 	Inner Iteration #  8 ,- Relative Error =  3.361302e-04
# 	Inner Iteration #  9 ,- Relative Error =  1.035509e-05
# 	Inner Iteration # 10 ,- Relative Error =  1.562630e-05
# 	Inner Iteration # 11 ,- Relative Error =  0.000000e+00
